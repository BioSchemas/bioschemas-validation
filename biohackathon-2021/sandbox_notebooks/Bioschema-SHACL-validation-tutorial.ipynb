# %% [markdown]
# # Interactive notebook supporting the Bioschemas tutorial presented at SWAT4LS'2022
#
# Learnig objectives are the following:
# - Loading Bioschemas markup into an RDF Knowledge Graph with Jupyter notebook, Python, RDFLib
# - Writing a simple SHACL shape
# - Evaluating it through the PySHACL library
# - Generating human-friendly validation result
# - Automating the generation of SHACL shapes with a textual template engine
# - Demoing the Bioschemas SHACL validator on some examples  (or local execution)
#
# Please ask any related question to alban.gaignard@univ-nantes.fr,
#
# or submit GitHub issues to https://github.com/BioSchemas/bioschemas-validation/issues

# %%
from rdflib import ConjunctiveGraph, URIRef
from rdflib.namespace import RDF
from pyshacl import validate
from jinja2 import Template
import requests
import json

# %% [markdown]
# # Step 1
# ## loading Bioschemas markup into an RDF Knowledge Graph

# %%
bioschemas_markup = """
@prefix ex: <http://bioschemas.validation.tutorial/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix schema: <http://schema.org/> .
@prefix prov: <http://www.w3.org/ns/prov#> .

ex:myTool rdf:type schema:SoftwareApplication, prov:SoftwareAgent ;
    schema:description "This tool does ... " ;
    schema:license <https://spdx.org/licenses/MIT.html> ;
    schema:codeRepository <http://github.com/> .
"""

kg = ConjunctiveGraph()
kg.parse(data=bioschemas_markup, format="turtle")
print(len(kg))
print()
print(kg.serialize(format="turtle"))
# Out:
# 5
#
# @prefix ex: <http://bioschemas.validation.tutorial/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix schema: <http://schema.org/> .
#
# ex:myTool a schema:SoftwareApplication,
#         prov:SoftwareAgent ;
#     schema:codeRepository <http://github.com/> ;
#     schema:description "This tool does ... " ;
#     schema:license <https://spdx.org/licenses/MIT.html> .

# %%
for s, p, o in kg.triples((None, None, None)):
    print(f'{s} --> {p} --> {o}')
# Out:
# http://bioschemas.validation.tutorial/myTool --> http://schema.org/codeRepository --> http://github.com/
# http://bioschemas.validation.tutorial/myTool --> http://schema.org/description --> This tool does ...
# http://bioschemas.validation.tutorial/myTool --> http://www.w3.org/1999/02/22-rdf-syntax-ns#type --> http://schema.org/SoftwareApplication
# http://bioschemas.validation.tutorial/myTool --> http://www.w3.org/1999/02/22-rdf-syntax-ns#type --> http://www.w3.org/ns/prov#SoftwareAgent
# http://bioschemas.validation.tutorial/myTool --> http://schema.org/license --> https://spdx.org/licenses/MIT.html

# %% [markdown]
# # Step 2
# ## writing and executing a simple SHACL shape

# %% [markdown]
# a SHACL shape checking that a `schema:description` is provided

# %%
##
shape_ok = """
        @prefix ns: <https://fair-checker.france-bioinformatique.fr#> .
        @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
        @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
        @prefix sc: <http://schema.org/> .
        @prefix bsc: <https://bioschemas.org/> .
        @prefix dct: <http://purl.org/dc/terms/> .
        @prefix sh: <http://www.w3.org/ns/shacl#> .
        @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
        @prefix edam: <http://edamontology.org/> .
        @prefix biotools: <https://bio.tools/ontology/> .

        ns:shape_1 a sh:NodeShape ;
            sh:targetClass  sc:SoftwareApplication ;

            sh:property [
                sh:path sc:description ;
                sh:minCount 1 ;
                sh:severity sh:Violation
            ] ;
        .
    """

# %%
shape_graph = ConjunctiveGraph()
shape_graph.parse(data=shape_ok, format="turtle")

r = validate(
        data_graph=kg,
        data_graph_format="turtle",
        shacl_graph=shape_graph,
        shacl_graph_format="turtle",
    )

conforms, results_graph, results_text = r

print(results_text)
# Out:
# Validation Report
# Conforms: True

# %% [markdown]
# Now, we verify that
# - a `schema:description`, AND a `schema:name` MUST BE present
# - a `schema:citation` SHOULD BE present

# %%
shape_more_strict = """
        @prefix ns: <https://fair-checker.france-bioinformatique.fr#> .
        @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
        @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
        @prefix sc: <http://schema.org/> .
        @prefix bsc: <https://bioschemas.org/> .
        @prefix dct: <http://purl.org/dc/terms/> .
        @prefix sh: <http://www.w3.org/ns/shacl#> .
        @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
        @prefix edam: <http://edamontology.org/> .
        @prefix biotools: <https://bio.tools/ontology/> .

        ns:shape_1 a sh:NodeShape ;
            sh:targetClass  sc:SoftwareApplication ;

            sh:property [
                sh:path sc:description ;
                sh:minCount 1 ;
                sh:severity sh:Violation
            ] ;
            
            sh:property [
                sh:path sc:name ;
                sh:minCount 1 ;
                sh:severity sh:Violation
            ] ;
            
            sh:property [
                sh:path sc:citation ;
                sh:minCount 1 ;
                sh:severity sh:Warning
            ] ;
        .
    """

# %%
shape_graph = ConjunctiveGraph()
shape_graph.parse(data=shape_more_strict, format="turtle")

r = validate(
        data_graph=kg,
        data_graph_format="turtle",
        shacl_graph=shape_graph,
        shacl_graph_format="turtle",
    )

conforms, results_graph, results_text = r

print(results_text)
# Out:
# Validation Report
# Conforms: False
# Results (2):
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path sc:name ; sh:severity sh:Violation ]
# 	Focus Node: ex:myTool
# 	Result Path: sc:name
# 	Message: Less than 1 values on ex:myTool->sc:name
# Validation Result in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Warning
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path sc:citation ; sh:severity sh:Warning ]
# 	Focus Node: ex:myTool
# 	Result Path: sc:citation
# 	Message: Less than 1 values on ex:myTool->sc:citation

# %% [markdown]
# We can obtain a human-readable report.
#
# What about a machine-readable report ?

# %%
print(results_graph.serialize(format="turtle"))
# Out:
# @prefix sc: <http://schema.org/> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# [] a sh:ValidationReport ;
#     sh:conforms false ;
#     sh:result [ a sh:ValidationResult ;
#             sh:focusNode <http://bioschemas.validation.tutorial/myTool> ;
#             sh:resultMessage "Less than 1 values on ex:myTool->sc:name" ;
#             sh:resultPath sc:name ;
#             sh:resultSeverity sh:Violation ;
#             sh:sourceConstraintComponent sh:MinCountConstraintComponent ;
#             sh:sourceShape [ sh:minCount 1 ;
#                     sh:path sc:name ;
#                     sh:severity sh:Violation ] ],
#         [ a sh:ValidationResult ;
#             sh:focusNode <http://bioschemas.validation.tutorial/myTool> ;
#             sh:resultMessage "Less than 1 values on ex:myTool->sc:citation" ;
#             sh:resultPath sc:citation ;
#             sh:resultSeverity sh:Warning ;
#             sh:sourceConstraintComponent sh:MinCountConstraintComponent ;
#             sh:sourceShape [ sh:minCount 1 ;
#                     sh:path sc:citation ;
#                     sh:severity sh:Warning ] ] .

# %% [markdown]
# We can query it and generate another a human-oriented representation.

# %%
report_query = """
    SELECT ?node ?path ?severity WHERE {
        # ?v rdf:type sh:ValidationReport ;
            sh:result ?r .
        # ?r sh:focusNode ?node ;
            sh:sourceShape ?s .
                # ?s sh:path ?path ;
                   sh:severity ?severity .
            }
        """

results = results_graph.query(report_query)

# %%
for r in results:
    if "#Warning" in r["severity"]:
        print(f'WARNING: Property {r["path"]} should be provided for {r["node"]}')
    if "#Violation" in r["severity"]:
        print(f'ERROR: Property {r["path"]} must be provided for {r["node"]}')
# Out:
# ERROR: Property http://schema.org/name must be provided for http://bioschemas.validation.tutorial/myTool
# WARNING: Property http://schema.org/citation should be provided for http://bioschemas.validation.tutorial/myTool

# %% [markdown]
# # Step 3
# ## Generate shapes  based on templates

# %%
minimal_properties = ["sc:name", "sc:description"]
recommended_properties = ["sc:citation", "sc:license"]

shape_template = """
        @prefix ns: <https://fair-checker.france-bioinformatique.fr#> .
        @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
        @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
        @prefix sc: <http://schema.org/> .
        @prefix bsc: <https://bioschemas.org/> .
        @prefix dct: <http://purl.org/dc/terms/> .
        @prefix sh: <http://www.w3.org/ns/shacl#> .
        @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
        @prefix edam: <http://edamontology.org/> .
        @prefix biotools: <https://bio.tools/ontology/> .

        ns:shape_1 a sh:NodeShape ;
            sh:targetClass  sc:SoftwareApplication ;

            {% for min_prop in minimal_properties %}
            sh:property [
                sh:path {{min_prop}} ;
                sh:minCount 1 ;
                sh:severity sh:Violation
            ] ;
            {% endfor %}

            {% for rec_prop in recommended_properties %}
            sh:property [
                sh:path {{rec_prop}} ;
                sh:minCount 1 ;
                sh:severity sh:Warning
            ] ;
            {% endfor %}
        .
"""

template = Template(shape_template)
shape = template.render(
        minimal_properties=minimal_properties,
        recommended_properties=recommended_properties,
)

print(shape)
# Out:
#         @prefix ns: <https://fair-checker.france-bioinformatique.fr#> .
#         @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#         @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#         @prefix sc: <http://schema.org/> .
#         @prefix bsc: <https://bioschemas.org/> .
#         @prefix dct: <http://purl.org/dc/terms/> .
#         @prefix sh: <http://www.w3.org/ns/shacl#> .
#         @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#         @prefix edam: <http://edamontology.org/> .
#         @prefix biotools: <https://bio.tools/ontology/> .
#
#         ns:shape_1 a sh:NodeShape ;
#             sh:targetClass  sc:SoftwareApplication ;
#
#
#             sh:property [
#                 sh:path sc:name ;
#                 sh:minCount 1 ;
#                 sh:severity sh:Violation
#             ] ;
#
#             sh:property [
#                 sh:path sc:description ;
#                 sh:minCount 1 ;
#                 sh:severity sh:Violation
#             ] ;
#
#
#
#             sh:property [
#                 sh:path sc:citation ;
#                 sh:minCount 1 ;
#                 sh:severity sh:Warning
#             ] ;
#
#             sh:property [
#                 sh:path sc:license ;
#                 sh:minCount 1 ;
#                 sh:severity sh:Warning
#             ] ;
#
#         .

# %% [markdown]
# # Step 4
# ## Trying the bioschemas-shacl-validator
#
# Due to missing system dependencies in the MyBinder default virtual machine, it is not yet possible to run the tool online.
#
# But you can run it on your local computer following the instructions from (https://github.com/BioSchemas/bioschemas-validation/blob/main/README.md#required-software-environment)

# %%
# %cd ../bioschemas_shacl
# !python main.py -u "https://bio.tools/jaspar"
# Out:
# /Users/gaignard-a/Documents/Dev/bioschemas/bioschemas-validation/bioschemas_shacl
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/gaignard-a/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# ──────────── Bioschemas validation for URL https://bio.tools/jaspar ────────────
# 95 retrieved triples in KG
# @prefix biotools: <https://bio.tools/ontology/> .
# @prefix bsc: <http://bioschemas.org/> .
# @prefix bsct: <http://bioschemas.org/types/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix edam: <http://edamontology.org/> .
# @prefix ns1: <http://ogp.me/ns#> .
# @prefix sc: <http://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <file:///Users/gaignard-a/Documents/Dev/bioschemas/bioschemas-validation/bioschemas_shacl/> ns1:description "{{ngMeta['og:description']}}" ;
#     ns1:image "{{ngMeta['og:image']}}" ;
#     ns1:title "{{ngMeta['og:title']}}" .
#
# <https://bio.tools/jaspar> a sc:SoftwareApplication ;
#     bsc:input <https://bio.tools/jaspar/op_1/in_1>,
#         <https://bio.tools/jaspar/op_1/in_2>,
#         <https://bio.tools/jaspar/op_1/in_3>,
#         <https://bio.tools/jaspar/op_1/in_4>,
#         <https://bio.tools/jaspar/op_1/in_5>,
#         <https://bio.tools/jaspar/op_1/in_6>,
#         <https://bio.tools/jaspar/op_1/in_7>,
#         <https://bio.tools/jaspar/op_2/in_1>,
#         <https://bio.tools/jaspar/op_2/in_2> ;
#     bsc:output <https://bio.tools/jaspar/op_1/in_1>,
#         <https://bio.tools/jaspar/op_2/in_1> ;
#     dct:conformsTo "https://bioschemas.org/profiles/ComputationalTool/1.0-RELEASE" ;
#     sc:applicationSubCategory edam:topic_0204,
#         edam:topic_0621,
#         edam:topic_0622,
#         edam:topic_0749,
#         edam:topic_0780,
#         edam:topic_2815 ;
#     sc:citation <https://doi.org/10.1093/bioinformatics/btx804>,
#         <https://doi.org/10.1093/nar/gkh012>,
#         <https://doi.org/10.1093/nar/gkj115>,
#         <https://doi.org/10.1093/nar/gkm955>,
#         <https://doi.org/10.1093/nar/gkp950>,
#         <https://doi.org/10.1093/nar/gkt997>,
#         <https://doi.org/10.1093/nar/gkv1176>,
#         <https://doi.org/10.1093/nar/gkx1126>,
#         "pubmed:14681366",
#         "pubmed:16381983",
#         "pubmed:18006571",
#         "pubmed:19906716",
#         "pubmed:24194598",
#         "pubmed:26531826",
#         "pubmed:29253085" ;
#     sc:featureList edam:operation_0445,
#         edam:operation_2421 ;
#     sc:isAccessibleForFree true ;
#     sc:softwareHelp <http://jaspar.genereg.net/api/v1/docs/>,
#         <http://jaspar.genereg.net/docs/>,
#         <http://jaspar.genereg.net/faq/> ;
#     biotools:primaryContact <http://orcid.org/0000-0001-5127-5459>,
#         "Albin Sandelin",
#         "Boris Lenhard",
#         "Wyeth Wasserman" .
#
# <http://orcid.org/0000-0001-5127-5459> a <schema:Person> .
#
# <https://bio.tools/jaspar/op_1/in_2> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_1077" ;
#     sc:name "Transcription factor identifier" ;
#     sc:sameAs "http://edamontology.org/data_1077" .
#
# <https://bio.tools/jaspar/op_1/in_3> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_1868" ;
#     sc:name "Taxon" ;
#     sc:sameAs "http://edamontology.org/data_1868" .
#
# <https://bio.tools/jaspar/op_1/in_4> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_2732" ;
#     sc:name "Family name" ;
#     sc:sameAs "http://edamontology.org/data_2732" .
#
# <https://bio.tools/jaspar/op_1/in_5> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_1045" ;
#     sc:name "Species name" ;
#     sc:sameAs "http://edamontology.org/data_1045" .
#
# <https://bio.tools/jaspar/op_1/in_6> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_2291" ;
#     sc:name "UniProt ID" ;
#     sc:sameAs "http://edamontology.org/data_2291" .
#
# <https://bio.tools/jaspar/op_1/in_7> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_3671" ;
#     sc:name "Text" ;
#     sc:sameAs "http://edamontology.org/data_3671" .
#
# <https://bio.tools/jaspar/op_2/in_2> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_1119" ;
#     sc:name "JASPAR profile ID" ;
#     sc:sameAs "http://edamontology.org/data_1119" .
#
# <https://doi.org/10.1093/bioinformatics/btx804> a sc:CreativeWork .
#
# <https://doi.org/10.1093/nar/gkh012> a sc:CreativeWork .
#
# <https://doi.org/10.1093/nar/gkj115> a sc:CreativeWork .
#
# <https://doi.org/10.1093/nar/gkm955> a sc:CreativeWork .
#
# <https://doi.org/10.1093/nar/gkp950> a sc:CreativeWork .
#
# <https://doi.org/10.1093/nar/gkt997> a sc:CreativeWork .
#
# <https://doi.org/10.1093/nar/gkv1176> a sc:CreativeWork .
#
# <https://doi.org/10.1093/nar/gkx1126> a sc:CreativeWork .
#
# <https://bio.tools/jaspar/op_1/in_1> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_1119",
#         "http://edamontology.org/data_2755" ;
#     sc:name "JASPAR profile ID",
#         "Transcription factor name" ;
#     sc:sameAs "http://edamontology.org/data_1119",
#         "http://edamontology.org/data_2755" .
#
# <https://bio.tools/jaspar/op_2/in_1> a bsct:FormalParameter ;
#     sc:identifier "http://edamontology.org/data_1119",
#         "http://edamontology.org/data_3494" ;
#     sc:name "DNA sequence",
#         "JASPAR profile ID" ;
#     sc:sameAs "http://edamontology.org/data_1119",
#         "http://edamontology.org/data_3494" .
#
#
#
# <https://bio.tools/jaspar/op_1/in_1> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_1/in_1 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_1/in_3> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_1/in_3 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_1/in_2> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_1/in_2 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_1/in_4> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_1/in_4 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_1/in_5> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_1/in_5 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_2/in_2> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_2/in_2 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_2/in_1> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_2/in_1 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_1/in_6> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_1/in_6 typed http://bioschemas.org/types/FormalParameter
#
# <https://bio.tools/jaspar/op_1/in_7> is a bsct:FormalParameter
# Could not find a suitable profile for https://bio.tools/jaspar/op_1/in_7 typed http://bioschemas.org/types/FormalParameter
#
# <https://doi.org/10.1093/nar/gkx1126> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/nar/gkx1126 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/nar/gkx1126
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/nar/gkx1126
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/nar/gkx1126
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/nar/gkx1126
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/nar/gkx1126
#
# <https://doi.org/10.1093/nar/gkv1176> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/nar/gkv1176 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/nar/gkv1176
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/nar/gkv1176
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/nar/gkv1176
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/nar/gkv1176
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/nar/gkv1176
#
# <https://doi.org/10.1093/bioinformatics/btx804> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/bioinformatics/btx804 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/bioinformatics/btx804
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/bioinformatics/btx804
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/bioinformatics/btx804
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/bioinformatics/btx804
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/bioinformatics/btx804
#
# <https://doi.org/10.1093/nar/gkh012> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/nar/gkh012 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/nar/gkh012
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/nar/gkh012
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/nar/gkh012
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/nar/gkh012
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/nar/gkh012
#
# <https://doi.org/10.1093/nar/gkp950> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/nar/gkp950 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/nar/gkp950
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/nar/gkp950
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/nar/gkp950
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/nar/gkp950
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/nar/gkp950
#
# <https://doi.org/10.1093/nar/gkt997> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/nar/gkt997 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/nar/gkt997
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/nar/gkt997
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/nar/gkt997
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/nar/gkt997
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/nar/gkt997
#
# <https://doi.org/10.1093/nar/gkj115> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/nar/gkj115 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/nar/gkj115
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/nar/gkj115
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/nar/gkj115
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/nar/gkj115
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/nar/gkj115
#
# <https://doi.org/10.1093/nar/gkm955> is a sc:CreativeWork
#
# Trying to validate https://doi.org/10.1093/nar/gkm955 as a(n) http://schema.org/CreativeWork resource
# Generating SHACL shape for sc:CreativeWork
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://doi.org/10.1093/nar/gkm955
# ERROR: Property http://schema.org/description must be provided for https://doi.org/10.1093/nar/gkm955
# ERROR: Property http://schema.org/keywords must be provided for https://doi.org/10.1093/nar/gkm955
# ERROR: Property http://schema.org/name must be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/about should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/abstract should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/audience should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/author should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/competencyRequired should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/educationalLevel should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/identifier should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/inLanguage should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/learningResourceType should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/license should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/mentions should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/teaches should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/timeRequired should be provided for https://doi.org/10.1093/nar/gkm955
# WARNING: Property http://schema.org/url should be provided for https://doi.org/10.1093/nar/gkm955
#
# <http://orcid.org/0000-0001-5127-5459> is a <schema:Person>
# Could not find a suitable profile for http://orcid.org/0000-0001-5127-5459 typed schema:Person
#
# <https://bio.tools/jaspar> is a sc:SoftwareApplication
#
# Trying to validate https://bio.tools/jaspar as a(n) http://schema.org/SoftwareApplication resource
# Generating SHACL shape for sc:SoftwareApplication
# ERROR: Property http://schema.org/name must be provided for https://bio.tools/jaspar
# ERROR: Property http://schema.org/description must be provided for https://bio.tools/jaspar
# ERROR: Property http://schema.org/url must be provided for https://bio.tools/jaspar
# WARNING: Property http://schema.org/additionalType should be provided for https://bio.tools/jaspar
# WARNING: Property http://schema.org/applicationCategory should be provided for https://bio.tools/jaspar
# WARNING: Property http://schema.org/author should be provided for https://bio.tools/jaspar
# WARNING: Property http://schema.org/license should be provided for https://bio.tools/jaspar
# WARNING: Property http://schema.org/softwareVersion should be provided for https://bio.tools/jaspar
# {
#     'https://doi.org/10.1093/nar/gkx1126': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/abstract for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/audience for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/author for https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/license for https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/mentions for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/teaches for https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/url for https://doi.org/10.1093/nar/gkx1126'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/description for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/keywords for
# https://doi.org/10.1093/nar/gkx1126',
#             'http://schema.org/name for https://doi.org/10.1093/nar/gkx1126'
#         ]
#     },
#     'https://doi.org/10.1093/nar/gkv1176': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/abstract for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/audience for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/author for https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/license for https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/mentions for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/teaches for https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/url for https://doi.org/10.1093/nar/gkv1176'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/description for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/keywords for
# https://doi.org/10.1093/nar/gkv1176',
#             'http://schema.org/name for https://doi.org/10.1093/nar/gkv1176'
#         ]
#     },
#     'https://doi.org/10.1093/bioinformatics/btx804': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/abstract for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/audience for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/author for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/license for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/mentions for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/teaches for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/url for
# https://doi.org/10.1093/bioinformatics/btx804'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/description for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/keywords for
# https://doi.org/10.1093/bioinformatics/btx804',
#             'http://schema.org/name for
# https://doi.org/10.1093/bioinformatics/btx804'
#         ]
#     },
#     'https://doi.org/10.1093/nar/gkh012': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/abstract for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/audience for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/author for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/license for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/mentions for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/teaches for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/url for https://doi.org/10.1093/nar/gkh012'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/description for
# https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/keywords for https://doi.org/10.1093/nar/gkh012',
#             'http://schema.org/name for https://doi.org/10.1093/nar/gkh012'
#         ]
#     },
#     'https://doi.org/10.1093/nar/gkp950': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/abstract for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/audience for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/author for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/license for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/mentions for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/teaches for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/url for https://doi.org/10.1093/nar/gkp950'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/description for
# https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/keywords for https://doi.org/10.1093/nar/gkp950',
#             'http://schema.org/name for https://doi.org/10.1093/nar/gkp950'
#         ]
#     },
#     'https://doi.org/10.1093/nar/gkt997': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/abstract for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/audience for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/author for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/license for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/mentions for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/teaches for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/url for https://doi.org/10.1093/nar/gkt997'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/description for
# https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/keywords for https://doi.org/10.1093/nar/gkt997',
#             'http://schema.org/name for https://doi.org/10.1093/nar/gkt997'
#         ]
#     },
#     'https://doi.org/10.1093/nar/gkj115': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/abstract for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/audience for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/author for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/license for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/mentions for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/teaches for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/url for https://doi.org/10.1093/nar/gkj115'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/description for
# https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/keywords for https://doi.org/10.1093/nar/gkj115',
#             'http://schema.org/name for https://doi.org/10.1093/nar/gkj115'
#         ]
#     },
#     'https://doi.org/10.1093/nar/gkm955': {
#         'type': 'http://schema.org/CreativeWork',
#         'warnings': [
#             'http://schema.org/about for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/abstract for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/audience for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/author for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/competencyRequired for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/educationalLevel for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/identifier for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/inLanguage for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/learningResourceType for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/license for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/mentions for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/teaches for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/timeRequired for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/url for https://doi.org/10.1093/nar/gkm955'
#         ],
#         'errors': [
#             'http://purl.org/dc/terms/conformsTo for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/description for
# https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/keywords for https://doi.org/10.1093/nar/gkm955',
#             'http://schema.org/name for https://doi.org/10.1093/nar/gkm955'
#         ]
#     },
#     'https://bio.tools/jaspar': {
#         'type': 'http://schema.org/SoftwareApplication',
#         'warnings': [
#             'http://schema.org/additionalType for https://bio.tools/jaspar',
#             'http://schema.org/applicationCategory for
# https://bio.tools/jaspar',
#             'http://schema.org/author for https://bio.tools/jaspar',
#             'http://schema.org/license for https://bio.tools/jaspar',
#             'http://schema.org/softwareVersion for https://bio.tools/jaspar'
#         ],
#         'errors': [
#             'http://schema.org/name for https://bio.tools/jaspar',
#             'http://schema.org/description for https://bio.tools/jaspar',
#             'http://schema.org/url for https://bio.tools/jaspar'
#         ]
#     }
# }
# ──────────── Bioschemas validation for URL https://bio.tools/jaspar ────────────
# [2022-01-10 16:21:42] {main.py:83} INFO     Bioschemas validation processed in 4.67 s

# %%
# !python main.py -u "https://bgee.org/?page=gene&gene_id=ENSG00000274928"
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/gaignard-a/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# ─ Bioschemas validation for URL https://bgee.org/?page=gene&gene_id=ENSG00000… ─
# [2022-01-10 16:26:08] {WebResource.py:127} WARNING  Can't find "application/ld+json" content
# @prefix bsc: <https://bioschemas.org/> .
# @prefix ns2: <http://www.w3.org/1999/xhtml/vocab#> .
# @prefix sc: <http://schema.org/> .
#
# <file:///Users/gaignard-a/Documents/Dev/bioschemas/bioschemas-validation/bioschemas_shacl/> ns2:license <https://creativecommons.org/publicdomain/zero/1.0/> .
#
# <http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928> a bsc:Gene .
#
# <https://bgee.org/?page=species&species_id=9606> bsc:name "Homo sapiens" .
#
# <https://oncomx.org/searchview/?gene=KRT89P> a bsc:Gene .
#
# <https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196> a bsc:Gene .
#
# [] a sc:WebPage ;
#     sc:name """
#
# Gene: KRT89P - ENSG00000274928
#  - Homo sapiens (human)
# """ ;
#     sc:url "https://bgee.org/?page=gene&gene_id=ENSG00000274928" .
#
# [] ns2:role ns2:button .
#
# [] ns2:role ns2:button .
#
# [] ns2:role ns2:button .
#
# [] a bsc:Gene ;
#     bsc:alternateName "hbb",
#         "krt123p",
#         "krthbp2" ;
#     bsc:description "keratin 89 pseudogene [Source:HGNC Symbol;Acc:HGNC:30196]" ;
#     bsc:name "KRT89P" ;
#     bsc:sameAs "ENSG00000274928",
#         "HGNC:30196",
#         "KRT89P" ;
#     bsc:taxonomicRange [ a bsc:Taxon ] .
#
# [] ns2:role ns2:button .
#
# [] ns2:role ns2:button .
#
# [] ns2:role ns2:button .
#
#
#
# _:Nb5cd7068307b40018867e744fba3e817 is a bsc:Taxon
# Could not find a suitable profile for Nb5cd7068307b40018867e744fba3e817 typed https://bioschemas.org/Taxon
#
# _:N7ba7de30c67744cda7a26efb9b61d421 is a bsc:Gene
#
# Trying to validate N7ba7de30c67744cda7a26efb9b61d421 as a(n) https://bioschemas.org/Gene resource
# Generating SHACL shape for bsc:Gene
# ERROR: Property http://schema.org/identifier must be provided for N7ba7de30c67744cda7a26efb9b61d421
# ERROR: Property http://schema.org/name must be provided for N7ba7de30c67744cda7a26efb9b61d421
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for N7ba7de30c67744cda7a26efb9b61d421
# WARNING: Property http://schema.org/description should be provided for N7ba7de30c67744cda7a26efb9b61d421
# WARNING: Property http://schema.org/encodesBioChemEntity should be provided for N7ba7de30c67744cda7a26efb9b61d421
# WARNING: Property http://schema.org/isPartOfBioChemEntity should be provided for N7ba7de30c67744cda7a26efb9b61d421
# WARNING: Property http://schema.org/url should be provided for N7ba7de30c67744cda7a26efb9b61d421
#
# <https://oncomx.org/searchview/?gene=KRT89P> is a bsc:Gene
#
# Trying to validate https://oncomx.org/searchview/?gene=KRT89P as a(n) https://bioschemas.org/Gene resource
# Generating SHACL shape for bsc:Gene
# ERROR: Property http://schema.org/identifier must be provided for https://oncomx.org/searchview/?gene=KRT89P
# ERROR: Property http://schema.org/name must be provided for https://oncomx.org/searchview/?gene=KRT89P
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://oncomx.org/searchview/?gene=KRT89P
# WARNING: Property http://schema.org/description should be provided for https://oncomx.org/searchview/?gene=KRT89P
# WARNING: Property http://schema.org/encodesBioChemEntity should be provided for https://oncomx.org/searchview/?gene=KRT89P
# WARNING: Property http://schema.org/isPartOfBioChemEntity should be provided for https://oncomx.org/searchview/?gene=KRT89P
# WARNING: Property http://schema.org/url should be provided for https://oncomx.org/searchview/?gene=KRT89P
#
# <http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928> is a bsc:Gene
#
# Trying to validate http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928 as a(n) https://bioschemas.org/Gene resource
# Generating SHACL shape for bsc:Gene
# ERROR: Property http://schema.org/identifier must be provided for http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928
# ERROR: Property http://schema.org/name must be provided for http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928
# WARNING: Property http://schema.org/description should be provided for http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928
# WARNING: Property http://schema.org/encodesBioChemEntity should be provided for http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928
# WARNING: Property http://schema.org/isPartOfBioChemEntity should be provided for http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928
# WARNING: Property http://schema.org/url should be provided for http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928
#
# <https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196> is a bsc:Gene
#
# Trying to validate https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196 as a(n) https://bioschemas.org/Gene resource
# Generating SHACL shape for bsc:Gene
# ERROR: Property http://schema.org/identifier must be provided for https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196
# ERROR: Property http://schema.org/name must be provided for https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196
# ERROR: Property http://purl.org/dc/terms/conformsTo must be provided for https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196
# WARNING: Property http://schema.org/description should be provided for https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196
# WARNING: Property http://schema.org/encodesBioChemEntity should be provided for https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196
# WARNING: Property http://schema.org/isPartOfBioChemEntity should be provided for https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196
# WARNING: Property http://schema.org/url should be provided for https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196
#
# _:N2f12f01b556d4d9e846930d742713339 is a sc:WebPage
# Could not find a suitable profile for N2f12f01b556d4d9e846930d742713339 typed http://schema.org/WebPage
# {
#     'N7ba7de30c67744cda7a26efb9b61d421': {
#         'type': 'https://bioschemas.org/Gene',
#         'warnings': [
#             'http://schema.org/description for
# N7ba7de30c67744cda7a26efb9b61d421',
#             'http://schema.org/encodesBioChemEntity for
# N7ba7de30c67744cda7a26efb9b61d421',
#             'http://schema.org/isPartOfBioChemEntity for
# N7ba7de30c67744cda7a26efb9b61d421',
#             'http://schema.org/url for N7ba7de30c67744cda7a26efb9b61d421'
#         ],
#         'errors': [
#             'http://schema.org/identifier for
# N7ba7de30c67744cda7a26efb9b61d421',
#             'http://schema.org/name for N7ba7de30c67744cda7a26efb9b61d421',
#             'http://purl.org/dc/terms/conformsTo for
# N7ba7de30c67744cda7a26efb9b61d421'
#         ]
#     },
#     'https://oncomx.org/searchview/?gene=KRT89P': {
#         'type': 'https://bioschemas.org/Gene',
#         'warnings': [
#             'http://schema.org/description for
# https://oncomx.org/searchview/?gene=KRT89P',
#             'http://schema.org/encodesBioChemEntity for
# https://oncomx.org/searchview/?gene=KRT89P',
#             'http://schema.org/isPartOfBioChemEntity for
# https://oncomx.org/searchview/?gene=KRT89P',
#             'http://schema.org/url for
# https://oncomx.org/searchview/?gene=KRT89P'
#         ],
#         'errors': [
#             'http://schema.org/identifier for
# https://oncomx.org/searchview/?gene=KRT89P',
#             'http://schema.org/name for
# https://oncomx.org/searchview/?gene=KRT89P',
#             'http://purl.org/dc/terms/conformsTo for
# https://oncomx.org/searchview/?gene=KRT89P'
#         ]
#     },
#     'http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274
# 928': {
#         'type': 'https://bioschemas.org/Gene',
#         'warnings': [
#             'http://schema.org/description for
# http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928',
#             'http://schema.org/encodesBioChemEntity for
# http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928',
#             'http://schema.org/isPartOfBioChemEntity for
# http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928',
#             'http://schema.org/url for
# http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928'
#         ],
#         'errors': [
#             'http://schema.org/identifier for
# http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928',
#             'http://schema.org/name for
# http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928',
#             'http://purl.org/dc/terms/conformsTo for
# http://mar2016.archive.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSG00000274928'
#         ]
#     },
#     'https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196':
# {
#         'type': 'https://bioschemas.org/Gene',
#         'warnings': [
#             'http://schema.org/description for
# https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196',
#             'http://schema.org/encodesBioChemEntity for
# https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196',
#             'http://schema.org/isPartOfBioChemEntity for
# https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196',
#             'http://schema.org/url for
# https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196'
#         ],
#         'errors': [
#             'http://schema.org/identifier for
# https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196',
#             'http://schema.org/name for
# https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196',
#             'http://purl.org/dc/terms/conformsTo for
# https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/HGNC%3A30196'
#         ]
#     }
# }
# ─ Bioschemas validation for URL https://bgee.org/?page=gene&gene_id=ENSG00000… ─
# [2022-01-10 16:26:09] {main.py:83} INFO     Bioschemas validation processed in 23.32 s
