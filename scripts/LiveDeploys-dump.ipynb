# %% [markdown]
# # Loading the LiveDeploys dump

# %%
from rdflib import ConjunctiveGraph
import seaborn as sns
import pandas as pd

kg = ConjunctiveGraph()
kg.parse("out.nq", format="nquads")
print(len(kg))
# Out:
# 74245

# %% [markdown]
# # Most used classes

# %%
query = """
    SELECT ?class (COUNT(?s) AS ?count ) { ?s a ?class } GROUP BY ?class ORDER BY desc(?count)
"""

results = kg.query(query)
data = []
for r in results:
    data.append({"class":r[0], "count":r[1]})
    print(r[0], r[1])
    
df = pd.DataFrame.from_dict(data)
df
# Out:
# http://schema.org/CreativeWork 14916
# http://schema.org/BioChemEntity 1085
# http://schema.org/DataDownload 910
# http://schema.org/creativeWork 714
# https://bioschemas.org/Taxon 714
# http://schema.org/Dataset 524
# http://schema.org/Organization 307
# http://schema.org/Person 256
# http://schema.org/DefinedTerm 159
# http://schema.org/MolecularEntity 113
# http://schema.org/DataSet 78
# http://schema.org/TaxonName 70
# http://schema.org/ChemicalSubstance 68
# http://schema.org/SequenceAnnotation 62
# http://schema.org/ScholarlyArticle 50
# http://schema.org/PropertyValue 47
# http://schema.org/SequenceRange 40
# http://schema.org/DataCatalog 32
# http://schema.org/PostalAddress 30
# http://schema.org/WebPage 28
# http://schema.org/LearningResource 28
# http://schema.org/Audience 26
# http://schema.org/WebSite 21
# http://schema.org/Place 19
# http://schema.org/Protein 16
# http://schema.org/NGO 16
# http://schema.org/Offer 16
# http://schema.org/BusinessEntityType 16
# http://schema.org/Event 14
# http://schema.org/ImageObject 14
# http://schema.org/SearchAction 14
# http://schema.org/CourseInstance 14
# http://schema.org/ListItem 12
# http://schema.org/EntryPoint 10
# http://schema.org/DefinedTermSet 10
# http://schema.org/Taxon 10
# http://schema.org/Course 10
# http://schema.org/SoftwareApplication 8
# http://schema.org/Text 6
# http://schema.org/Action 6
# http://schema.org/dataDownload 6
# http://schema.org/Gene 6
# http://schema.org/PublicationEvent 5
# http://schema.org/DataRecord 4
# http://schema.org/MedicalCode 4
# http://schema.org/dataSet 4
# http://schema.org/dataset 4
# http://schema.org/Language 4
# http://schema.org/EducationalAudience 4
# http://schema.org/FormalParameter 4
# http://rdf.data-vocabulary.org/#Breadcrumb 4
# http://schema.org/MedicalCondition 3
# http://schema.org/ContactPoint 3
# http://schema.org/VirtualLocation 2
# http://schema.org/GeoShape 2
# http://schema.org/PronounceableText 2
# http://schema.org/dataCatalog 2
# http://schema.org/ReadAction 2
# http://schema.org/ControlAction 2
# https://bioschemas.org/DataRecord 2
# http://schema.org/Thing 2
# http://schema.org/BioSample 2
# https://schema.org/Dataset 2
# https://schema.org/PropertyValue 2
# https://schema.org/DataCatalog 2
# http://schema.org/CreateAction 2
# http://schema.org/Project 2
# http://schema.org/GeoCoordinates 2
# http://schema.org/Breadcrumblist 2
# http://schema.org/imageObject 2
# http://schema.org/BreadcrumbList 1
# http://schema.org/EducationalOrganization 1
# http://schema.org/CollegeOrUniversity 1
# http://schema.org/Study 1
# http://schema.org/Product 1
# https://schema.org/Protein 1
# http://bioschemas.org/types/FormalParameter 1
# http://schema.org/ComputationalWorkflow 1
# http://schema.org/SoftwareSourceCode 1
# http://schema.org/ComputerLanguage 1
# http://bioschemas.org/Protein 1
# http://bioschemas.org/taxon 1
# http://xmlns.com/foaf/0.1/Document 1
# http://rdfs.org/sioc/ns#Item 1
# http://xmlns.com/foaf/0.1/Image 1
# http://schema.org/WebPageElement 1
# http://schema.org/ResearchOrganization 1
#                                      class  count
# 0           http://schema.org/CreativeWork  14916
# 1          http://schema.org/BioChemEntity   1085
# 2           http://schema.org/DataDownload    910
# 3           http://schema.org/creativeWork    714
# 4             https://bioschemas.org/Taxon    714
# ..                                     ...    ...
# 82      http://xmlns.com/foaf/0.1/Document      1
# 83            http://rdfs.org/sioc/ns#Item      1
# 84         http://xmlns.com/foaf/0.1/Image      1
# 85        http://schema.org/WebPageElement      1
# 86  http://schema.org/ResearchOrganization      1
#
# [87 rows x 2 columns]

# %% [markdown]
# # Most used properties

# %%
query = """
    SELECT ?p (COUNT(?s) AS ?count ) { ?s ?p ?o } GROUP BY ?p ORDER BY desc(?count)
"""

results = kg.query(query)
data = []
for r in results:
    data.append({"property":r[0], "count":r[1]})
    print(r[0], r[1])
    
df = pd.DataFrame.from_dict(data)
df
# Out:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type 20595
# http://schema.org/name 20537
# http://schema.org/url 12281
# http://schema.org/about 5716
# http://schema.org/identifier 1616
# http://schema.org/taxonRank 1158
# http://schema.org/taxonomicRange 1083
# http://schema.org/parentTaxon 1078
# http://schema.org/studySubject 1074
# http://schema.org/@Type 1074
# http://schema.org/distribution 916
# http://schema.org/description 607
# http://schema.org/keywords 578
# http://purl.org/dc/terms/conformsTo 562
# http://schema.org/version 444
# http://schema.org/author 311
# http://schema.org/license 200
# http://schema.org/contentURL 178
# http://schema.org/creator 164
# http://schema.org/sameAs 161
# http://schema.org/alternateName 157
# http://schema.org/associatedDisease 123
# http://schema.org/isInvolvedInBiologicalProcess 99
# http://schema.org/email 93
# http://schema.org/givenName 88
# http://schema.org/familyName 88
# http://schema.org/image 86
# http://schema.org/dataset 84
# http://schema.org/logo 80
# http://schema.org/encodingFormat 80
# http://schema.org/datePublished 70
# http://schema.org/valueReference 70
# http://schema.org/isBasedOn 69
# http://schema.org/instructor 65
# http://schema.org/alternateScientificName 64
# http://schema.org/sequenceLocation 64
# http://schema.org/sequenceValue 63
# http://schema.org/hasSequenceAnnotation 63
# http://schema.org/creationMethod 62
# http://schema.org/measurementTechnique 61
# http://schema.org/subjectOf 61
# http://schema.org/provider 60
# http://schema.org/citation 53
# http://schema.org/isAccessibleForFree 48
# http://ogp.me/ns#image 45
# http://schema.org/headline 44
# http://schema.org/affiliation 40
# http://schema.org/rangeEnd 40
# http://schema.org/rangeStart 40
# http://rs.tdwg.org/dwc/terms/vernacularName 40
# http://schema.org/publisher 39
# http://ogp.me/ns#title 38
# http://schema.org/value 37
# http://schema.org/addressLocality 35
# http://ogp.me/ns#description 35
# http://schema.org/uploadDate 34
# http://schema.org/inDefinedTermSet 34
# http://schema.org/address 34
# http://schema.org/addressCountry 34
# http://schema.org/audience 33
# http://schema.org/inLanguage 32
# http://schema.org/funder 30
# http://schema.org/postalCode 29
# http://schema.org/streetAddress 29
# http://schema.org/potentialAction 28
# http://schema.org/dateModified 28
# http://schema.org/founder 28
# http://schema.org/mainEntityOfPage 27
# http://schema.org/termCode 27
# http://schema.org/location 27
# http://ogp.me/ns#url 25
# http://schema.org/isLocatedInSubcellularLocation 25
# http://schema.org/propertyID 25
# http://schema.org/hasPart 24
# http://schema.org/memberOf 23
# http://schema.org/offers 22
# http://schema.org/fileFormat 22
# http://ogp.me/ns#type 21
# http://schema.org/audienceType 20
# http://schema.org/startDate 20
# http://schema.org/price 20
# http://schema.org/target 20
# http://schema.org/endDate 20
# http://schema.org/priceCurrency 20
# http://schema.org/teaches 20
# http://ogp.me/ns#site_name 19
# http://schema.org/additionalType 19
# http://schema.org/contentUrl 19
# http://schema.org/addressRegion 19
# http://schema.org/educationalLevel 18
# http://schema.org/sourceOrganization 18
# http://schema.org/courseMode 17
# http://schema.org/featureList 17
# http://schema.org/eligibleCustomerType 16
# http://ogp.me/ns#locale 16
# http://schema.org/hasCourseInstance 15
# http://ogp.me/ns#image:secure_url 15
# http://schema.org/parentOrganization 15
# http://schema.org/organizer 14
# http://schema.org/Keywords 14
# http://schema.org/contributor 14
# http://schema.org/isPartOf 14
# https://dev.twitter.com/cards#title 14
# http://schema.org/abstract 13
# http://schema.org/orcid 13
# http://schema.org/query-input 12
# http://schema.org/dateCreated 12
# http://schema.org/includedInDataCatalog 12
# http://schema.org/position 12
# http://schema.org/itemListElement 12
# http://schema.org/variableMeasured 11
# http://schema.org/operatingSystem 10
# http://schema.org/item 10
# http://schema.org/urlTemplate 10
# http://schema.org/bioChemInteraction 10
# http://schema.org/publication 9
# http://schema.org/memberof 8
# http://schema.org/learningResourceType 8
# http://schema.org/softwareHelp 8
# http://ogp.me/ns#image:title 8
# http://schema.org/MemberOf 8
# http://schema.org/httpMethod 7
# http://schema.org/contentType 7
# http://schema.org/encodingType 7
# http://schema.org/workFeatured 7
# http://schema.org/result 6
# http://schema.org/eventStatus 6
# http://ogp.me/ns#image:height 6
# http://ogp.me/ns#image:description 6
# http://schema.org/applicationCategory 6
# http://ogp.me/ns#image:width 6
# http://schema.org/object 6
# http://schema.org/scientificName 6
# http://schema.org/additionalName 6
# http://schema.org/contactPoint 5
# http://schema.org/smiles 5
# http://schema.org/includedInDataset 5
# http://schema.org/genre 5
# http://schema.org/molecularFormula 5
# http://schema.org/maximumAttendeeCapacity 5
# http://schema.org/inChI 5
# http://schema.org/jobTitle 5
# http://schema.org/inChIKey 5
# http://schema.org/educationalRole 4
# http://schema.org/accessibilityControl 4
# http://schema.org/duration 4
# http://rdf.data-vocabulary.org/#url 4
# http://schema.org/priceValidUntil 4
# http://schema.org/additionalProperty 4
# http://schema.org/longitude 4
# http://schema.org/geo 4
# http://schema.org/code 4
# http://schema.org/accessModeSufficient 4
# http://schema.org/codingSystem 4
# http://schema.org/latitude 4
# http://schema.org/input 4
# http://schema.org/accessMode 4
# http://schema.org/softwareVersion 4
# http://schema.org/thumbnailUrl 4
# http://schema.org/mainEntity 4
# http://schema.org/hasRepresentation 4
# http://schema.org/codeValue 4
# http://schema.org/includedinDataCatalog 4
# http://ogp.me/ns/fb#app_id 4
# http://schema.org/applicationSubCategory 4
# http://schema.org/accessibilityFeature 4
# http://rdf.data-vocabulary.org/#title 4
# https://schema.org/name 3
# http://schema.org/hasBioPolymerSequence 3
# http://schema.org/contactType 3
# http://schema.org/molecularWeight 3
# http://schema.org/producer 3
# http://schema.org/eventAttendanceMode 3
# http://schema.org/monoisotopicMolecularWeight 3
# https://api.w.org/ 3
# https://ogp.me/ns#image:secure_url 2
# http://schema.org/textValue 2
# http://ogp.me/ns#image:type 2
# http://schema.org/coursePrerequisites 2
# http://schema.org/copyrightHolder 2
# http://schema.org/spatialCoverage 2
# http://ogp.me/ns/article#modified_time 2
# http://schema.org/telephone 2
# http://schema.org/eventType 2
# http://schema.org/gender 2
# https://ogp.me/ns#title 2
# http://purl.org/ppeo/PPEO.owl#hasType 2
# http://purl.org/dc/terms/date 2
# http://schema.org/collector 2
# https://ogp.me/ns#url 2
# https://ogp.me/ns#description 2
# http://schema.org/custodian 2
# http://schema.org/width 2
# https://ogp.me/ns#image 2
# http://schema.org/dataSet 2
# https://ogp.me/ns#image:type 2
# https://schema.org/sameAs 2
# http://schema.org/samplingAge 2
# http://purl.org/ppeo/PPEO.owl#hasGrowthFacility 2
# http://purl.org/dc/terms/conformsTo. 2
# http://schema.org/box 2
# http://schema.org/locationCreated 2
# http://schema.org/interactivityType 2
# https://ogp.me/ns#image:width 2
# http://schema.org/discussionUrl 2
# http://schema.org/sameas 2
# https://ogp.me/ns#image:height 2
# https://dev.twitter.com/cards#description 2
# http://schema.org/timeRequired 2
# http://schema.org/accessibilitySummary 2
# http://schema.org/creativeWorkStatus 2
# http://schema.org/maintainer 2
# https://ogp.me/ns#type 2
# http://schema.org/height 2
# http://schema.org/isFamilyFriendly 2
# https://schema.org/variableMeasured 2
# http://schema.org/epidemiology 1
# http://schema.org/sdPublisher 1
# http://schema.org/chemicalComposition 1
# http://purl.org/dc/terms/onformsTo 1
# http://schema.org/studyProcess 1
# http://ogp.me/ns/article#published_time 1
# http://ogp.me/ns/fb#admins 1
# http://schema.org/superEvent 1
# http://schema.org/category 1
# http://schema.org/encodesBioChemEntity 1
# http://schema.org/isPartOfBioChemEntity 1
# http://schema.org/eligibility 1
# http://bioschemas.org/output 1
# http://schema.org/manufacturer 1
# http://schema.org/hostInstitution 1
# https://dev.twitter.com/cards#site 1
# https://bio.tools/ontology/primaryContact 1
# https://schema.org/image 1
# http://bioschemas.org/input 1
# https://dev.twitter.com/cards#creator 1
# http://schema.org/event_types 1
# http://schema.org/material 1
# http://schema.org/caption 1
# https://dev.twitter.com/cards#card 1
# https://schema.org/taxonomicRange 1
# http://purl.org/dc/terms/title 1
# http://ogp.me/ns#locale:alternate 1
# http://schema.org/worksFor 1
# http://schema.org/accountablePerson 1
# https://schema.org/identifier 1
# http://schema.org/temporalCoverage 1
# https://schema.org/url 1
# http://schema.org/hasBioChemEntityPart 1
# http://schema.org/programmingLanguage 1
# http://schema.org/breadcrumb 1
# http://ogp.me/ns#updated_time 1
# http://schema.org/primaryImageOfPage 1
# http://schema.org/legalName 1
# https://schema.org/hasRepresentation 1
#                                             property  count
# 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type  20595
# 1                             http://schema.org/name  20537
# 2                              http://schema.org/url  12281
# 3                            http://schema.org/about   5716
# 4                       http://schema.org/identifier   1616
# ..                                               ...    ...
# 250                     http://schema.org/breadcrumb      1
# 251                    http://ogp.me/ns#updated_time      1
# 252             http://schema.org/primaryImageOfPage      1
# 253                      http://schema.org/legalName      1
# 254             https://schema.org/hasRepresentation      1
#
# [255 rows x 2 columns]

# %% [markdown]
# # DefinedTerms

# %%
query = """
SELECT Distinct ?s WHERE {
    VALUES ?o { <http://schema.org/DefinedTerm> <http://schema.org/DefinedTermSet> }
    # ?s ?p ?o
} 

"""

results = kg.query(query)
for r in results:
    print(r["s"])
# Out:
# Neb84024e8ce148a09ba564ab315883ff
# N2aee2730fd484ecfbe110d63a70998a3
# N2bc495323805416f9aeea6e59d8ca561
# Na1b2284bae6c41ecaf0c6267d85b6885
# N7751f4816429488690db607f9153c1e8
# Nacec4499ebe041e6b8da2c3752d974d6
# https://disprot.org/IDPO/IDPO:00499
# https://disprot.org/IDPO/IDPO:00076
# Ncfdddc3d7fba4a3c9872d2b40b3b806e
# http://edamontology.org/topic_4019
# http://edamontology.org/topic_3474
# http://edamontology.org/topic_0091
# https://disprot.org/IDPO/GO:0140677
# https://disprot.org/IDPO/IDPO:00025
# https://disprot.org/IDPO/GO:0031625
# Nf26c9a5dc03540ed9f8ec251ff98c34b
# https://disprot.org/IDPO/IDPO:00506
# https://disprot.org/IDPO/IDPO:00026
# https://disprot.org/IDPO/IDPO:00027
# https://disprot.org/IDPO/IDPO:00050
# https://disprot.org/IDPO/GO:0005515
# https://disprot.org/IDPO/GO:0071889
# http://www.ebi.ac.uk/SAMEA104493311
# http://www.ebi.ac.uk/efo/EFO_0004236
# edam:http:/edamontology.org/operation_2421
# edam:http:/edamontology.org/topic_3174
# edam:http:/edamontology.org/topic_3837
# N4627ad2844544795a6112ed90ce6b7cf
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051248
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043230
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0070613
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0070062
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044765
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043547
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0080134
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0052547
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0045088
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044092
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0009987
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044464
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0065009
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051234
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0048869
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043226
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043227
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0005576
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031982
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044763
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0007597
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0045055
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031974
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0010951
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:1902531
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002683
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044699
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0030162
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0006887
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0010629
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043086
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0010466
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0072376
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0050789
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051056
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0032268
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0010468
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044446
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031347
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:1902578
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0005615
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0023051
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002920
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0065007
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0030449
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044433
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0048523
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0030154
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043085
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0050790
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:1903561
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043233
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0070013
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0045824
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002698
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0010955
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044422
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:2000257
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0010605
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0001869
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0006810
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0032940
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0052548
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0050727
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0045861
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044444
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:1903317
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0030198
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0045916
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0072562
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0071840
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051345
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0080090
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002682
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0016192
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031323
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0032269
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0046903
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043062
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0071704
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043170
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0060205
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051179
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0060255
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0048583
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031093
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031324
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0001868
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044093
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051346
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051336
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031348
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:2000258
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0050776
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0051246
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0034774
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0016043
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002673
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002921
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031983
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0005829
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044424
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0022617
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0009892
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0043087
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002697
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0009966
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0010646
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0022411
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0031988
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0032101
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0050896
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044421
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0002576
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0048863
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0048585
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0008152
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0048519
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0019222
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0050777
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0050794
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0019538
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0044238
# http://www.ebi.ac.uk/QuickGO/GTerm?id=GO:1903318
# Naf387bb1c9f44bbd99030410dc119325
# http://edamontology.org/topic_0089
# http://edamontology.org/topic_3063
# Ne63c3526d221459793b4521578dc42d5
# N4ac7e8ca627b4f9fb56e2f3928fa2265
# Ne879a31cd813469ca020886f8a415c6e
# N3c652f1d41c044e7907f8dfac4e2e0e5
# https://disprot.org/assets/data/IDPO_v0.3.0.owl
# https://disprot.org/assets/data/IDPO_v0.3.owl
# Ne411754bcc114b79b99ecd9796a71526
# Nc841d923683548be8c110a097a9ca510
# N763279955c7843f18e32be17481bb1be
# N51e605845f984e3a9f1987ddfb91988f
# Ndbb100914ecf421aa4df41c637f8c705
# N1a78ebda7afd4b0e88ed75e96116a9a9
# N04a45e9aba39450595d68acbad9ed256
# N57f7eab755a749cda714935d0ca6b72d
